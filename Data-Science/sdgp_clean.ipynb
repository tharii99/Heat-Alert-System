# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
gen_data =pd.read_csv('/content/gdrive/My Drive/Dataset/Plant_1_Generation_Data.csv')
gen_data.drop(['PLANT_ID', 'SOURCE_KEY'], axis='columns', inplace=True)
gen_data.head(50)
# Out:
#            DATE_TIME  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD
# 0   15-05-2020 00:00       0.0       0.0          0.0    6259559.0
# 1   15-05-2020 00:00       0.0       0.0          0.0    6183645.0
# 2   15-05-2020 00:00       0.0       0.0          0.0    6987759.0
# 3   15-05-2020 00:00       0.0       0.0          0.0    7602960.0
# 4   15-05-2020 00:00       0.0       0.0          0.0    7158964.0
# 5   15-05-2020 00:00       0.0       0.0          0.0    7206408.0
# 6   15-05-2020 00:00       0.0       0.0          0.0    7028673.0
# 7   15-05-2020 00:00       0.0       0.0          0.0    6522172.0
# 8   15-05-2020 00:00       0.0       0.0          0.0    7098099.0
# 9   15-05-2020 00:00       0.0       0.0          0.0    6271355.0
# 10  15-05-2020 00:00       0.0       0.0          0.0    6316803.0
# 11  15-05-2020 00:00       0.0       0.0          0.0    7177992.0
# 12  15-05-2020 00:00       0.0       0.0          0.0    6185184.0
# ...

# %%
gen_data.drop_duplicates(subset=['DATE_TIME'])
gen_data.to_csv('/content/gdrive/My Drive/Dataset/Generation_Data.csv', index=False)

# %%
import pandas as pd
weather_data = pd.read_csv('/content/gdrive/My Drive/Dataset/Plant_1_Weather_Sensor_Data.csv')
print(weather_data)
# Out:
#             DATE_TIME  PLANT_ID  ... MODULE_TEMPERATURE  IRRADIATION
# 0      5/15/2020 0:00   4135001  ...          22.857507          0.0
# 1      5/15/2020 0:15   4135001  ...          22.761668          0.0
# 2      5/15/2020 0:30   4135001  ...          22.592306          0.0
# 3      5/15/2020 0:45   4135001  ...          22.360852          0.0
# 4      5/15/2020 1:00   4135001  ...          22.165423          0.0
# ...               ...       ...  ...                ...          ...
# 3177  6/17/2020 22:45   4135001  ...          21.480377          0.0
# 3178  6/17/2020 23:00   4135001  ...          21.389024          0.0
# 3179  6/17/2020 23:15   4135001  ...          20.709211          0.0
# 3180  6/17/2020 23:30   4135001  ...          20.734963          0.0
# 3181  6/17/2020 23:45   4135001  ...          20.427972          0.0
#
# [3182 rows x 6 columns]

# %%
import pandas as pd
new_data = pd.read_csv('/content/gdrive/My Drive/Dataset/Generation_Data.csv')
print(new_data)
# Out:
#               DATE_TIME  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD
# 0      15-05-2020 00:00       0.0       0.0        0.000    6259559.0
# 1      15-05-2020 00:00       0.0       0.0        0.000    6183645.0
# 2      15-05-2020 00:00       0.0       0.0        0.000    6987759.0
# 3      15-05-2020 00:00       0.0       0.0        0.000    7602960.0
# 4      15-05-2020 00:00       0.0       0.0        0.000    7158964.0
# ...                 ...       ...       ...          ...          ...
# 68773  17-06-2020 23:45       0.0       0.0     5967.000    7287002.0
# 68774  17-06-2020 23:45       0.0       0.0     5147.625    7028601.0
# 68775  17-06-2020 23:45       0.0       0.0     5819.000    7251204.0
# 68776  17-06-2020 23:45       0.0       0.0     5817.000    6583369.0
# 68777  17-06-2020 23:45       0.0       0.0     5910.000    7363272.0
#
# [68778 rows x 5 columns]

# %%
import pandas as pd
merged_data = pd.merge(gen_data, weather_data, on = 'DATE_TIME')
print(merged_data)
